# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.manifold import TSNE,Isomap
from umap import UMAP
import pandas as pd

# %%
n_samples = 10000
n_features = 10
n_informative = 8
n_redundant = 2
n_classes = 2

X, y = make_classification(
    n_samples=n_samples, 
    n_features=n_features, 
    n_classes=n_classes, 
    n_informative=n_informative, 
    n_redundant=n_redundant, 
    n_clusters_per_class=2, 
    class_sep=1.5, 
    random_state=42
)

# %%
feature_names = [f'feature_{i+1}' for i in range(n_features)]


df_features = pd.DataFrame(X, columns=feature_names)


df = df_features.copy()
df['target'] = y
df
# Out:
#       feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0     -2.482531   0.525135  -0.598951  -2.410959  -0.990930  -3.112120
# 1     -2.842556  -0.564530   0.096068  -0.815907   3.120619  -0.256869
# 2      3.080255   1.789750   1.771519   2.924127  -1.811381  -1.350302
# 3     -0.647513  -3.790428   2.014160  -0.585143   1.626927  -5.255379
# 4     -0.731565   0.873713   1.726333   2.005599  -1.218096   0.728442
# ...         ...        ...        ...        ...        ...        ...
# 9995  -1.999463  -2.826460  -0.703037   2.727000  -2.420999  -0.465184
# 9996   3.959000   1.900724   1.585159   2.672286  -4.300224  -3.274783
# 9997  -3.021406  -2.273686   4.344588  -1.683138   3.043479  -3.205070
# 9998   0.969112   3.597363   3.037797   0.119398   0.094230  -1.240834
# 9999   2.283326   4.032966   3.894216   3.038547  -0.165755   0.285279
#
#       feature_7  feature_8  feature_9  feature_10  target
# 0     -2.840507  -0.572464   3.171115   -0.782214       1
# 1     -5.424947   0.809551   0.058091    8.011134       1
# 2      2.976814  -0.158628   2.734609   -7.104737       0
# 3      0.320723   3.078251   0.862170   -3.282414       0
# 4      3.282940  -2.123311   3.492206   -8.392934       0
# ...         ...        ...        ...         ...     ...
# 9995   0.605673  -0.721480   3.900589   -9.932152       0
# 9996   1.397944  -3.899414  -0.424083   -8.202205       0
# 9997  -2.935192   4.993852   2.917857    2.610618       0
# 9998   0.838637  -2.383345   1.121974   -1.066480       0
# 9999   3.264131  -0.419280   4.302087   -5.197609       0
#
# [10000 rows x 11 columns]

# %%
df["target"].value_counts()
# Out:
# target
# 0    5001
# 1    4999
# Name: count, dtype: int64
